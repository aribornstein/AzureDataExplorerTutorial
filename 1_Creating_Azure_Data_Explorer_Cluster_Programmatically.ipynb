# %% [markdown]
# # Part 1 Create Cluster

# %%
from azure.common.credentials import ServicePrincipalCredentials
from azure.mgmt.resource import ResourceManagementClient
from azure.mgmt.resource.resources.models import DeploymentMode

# %% [markdown]
# ## Get and Set Azure Credentials

# %%
# !az login

# %%
# !az ad sp create-for-rbac --sdk-auth > mycredentials.json
# Out:
# Retrying role assignment creation: 1/36

# %%
import os, json
with open('mycredentials.json') as data_file:    
    azure_session = json.load(data_file)
# delete credentials file
os.remove("mycredentials.json")

# %% [markdown]
# ## Create Azure Resource Manager Client

# %%
credentials = ServicePrincipalCredentials(
    client_id=azure_session["clientId"],
    secret=azure_session["clientSecret"],
    tenant=azure_session["tenantId"]
)
client = ResourceManagementClient(credentials, azure_session["subscriptionId"])

# %% [markdown]
# ## Resource Group Parameters

# %%
RESOURCE_GROUP_NAME = 'kustodeploymenttest' # Set resource group name here
AZURE_REGION = 'East US' # Set region here
location = ''.join(AZURE_REGION.split()).lower()

# %% [markdown]
# ## Set Azure Data Explorer Cluster Parameters

# %%
CLUSTER_NAME = 'cdacluster'
CLUSTER_NODE_SIZE = 'D13_v2'
CLUSTER_NODE_TEIR = 'Standard'
CLUSTER_NODE_CAPACITY = 2

# %% [markdown]
# ## Set Azure Data Explorer DB Deployment Parameters

# %%
DB_NAME = 'cdadb'
DB_SOFT_DELETION_PERIOD = 3650
DB_HOT_CACHE_PERIOD = 31

# %% [markdown]
# ## Define Azure Data Explorer Deployment Template

# %%
URI = "https://{}.{}.kusto.windows.net:443".format(CLUSTER_NAME, location)
DATA_INGESTION_URI = "https://ingest-{}.{}.kusto.windows.net:443/".format(CLUSTER_NAME, location)
template = {\
    "$schema": "https://schema.management.azure.com/schemas/2015-01-01/deploymentTemplate.json#",
    "contentVersion": "1.0.0.0",
    "resources": [\
        {\
            "type": "Microsoft.Kusto/Clusters",
            "sku": {\
                "name": CLUSTER_NODE_SIZE,
                "tier": CLUSTER_NODE_TEIR,
                "capacity": CLUSTER_NODE_CAPACITY
            },
            "name": CLUSTER_NAME,
            "apiVersion": "2017-09-07-privatepreview",
            "location": AZURE_REGION,
            "properties": {\
                "trustedExternalTenants": [
                    {
                        "value": azure_session["tenantId"]
                    }
                ],                
            }
        },
        {\
            "type": "Microsoft.Kusto/Clusters/Databases",
            "name": "{}/{}".format(CLUSTER_NAME, DB_NAME),
            "apiVersion": "2017-09-07-privatepreview",
            "location": AZURE_REGION,
            "properties": {
                "softDeletePeriodInDays": DB_SOFT_DELETION_PERIOD,
                "hotCachePeriodInDays": DB_HOT_CACHE_PERIOD,
            },
            "dependsOn": [\
                "[resourceId('Microsoft.Kusto/Clusters', '{}')]".format(CLUSTER_NAME)
            ]
        }
    ]
}

# %%
deployment_properties = {
    'mode': DeploymentMode.incremental,
    'template': template,
}

# %% [markdown]
# ## Create Resource Group and Deploy
#
# Note this could take 10-15 min

# %%
resource_group_params = {'location':location}
client.resource_groups.create_or_update('kustodeploymenttest', resource_group_params)

# https://docs.microsoft.com/en-us/python/api/azure-mgmt-resource/azure.mgmt.resource.resources.v2018_05_01.operations.deploymentsoperations?view=azure-python#create-or-update
deployment_async_operation = client.deployments.create_or_update(
    RESOURCE_GROUP_NAME,
    'azure-sample',
    deployment_properties
)
deployment_async_operation.wait()

# %% [markdown]
# # Part 2 Populate Cluster

# %%
# Install Perquisite Libraries
# !pip install azure-kusto-data==0.0.13
# !pip install azure-kusto-ingest==0.0.13

# %% [markdown]
# ## Batch Ingestion

# %% [markdown]
# ### Import Statements and Set Constants

# %%
from azure.kusto.data.request import KustoClient, KustoConnectionStringBuilder
from azure.kusto.data.exceptions import KustoServiceError
from azure.kusto.data.helpers import dataframe_from_result_table
import pandas as pd
import datetime

# %%
# Construct the connection string. In this example we are using key authentication, 
# alternate options are AAD Application Certificate, AAD Application Key, and AAD User Password. 
# More samples available @ # https://github.com/Azure/azure-kusto-python/blob/master/azure-kusto-data/tests/sample.py

KCSB_INGEST = KustoConnectionStringBuilder.with_aad_application_key_authentication(DATA_INGESTION_URI,
                                                                            azure_session["clientId"],
                                                                            azure_session["clientSecret"],
                                                                            azure_session["tenantId"])

KCSB_ENGINE = KustoConnectionStringBuilder.with_aad_application_key_authentication(URI,
                                                                            azure_session["clientId"],
                                                                            azure_session["clientSecret"],
                                                                            azure_session["tenantId"])

DESTINATION_TABLE = "StormEvents"
DESTINATION_TABLE_COLUMN_MAPPING = "StormEvents_CSV_Mapping"

# %% [markdown]
# ### Set Source File Information
#
# In this example, we are using sample file hosted on Azure Blob Storage

# %%
from azure.storage.blob import BlockBlobService
from azure.kusto.ingest import KustoIngestClient, IngestionProperties, FileDescriptor, BlobDescriptor, DataFormat, ReportLevel, ReportMethod

CONTAINER = "samplefiles"
ACCOUNT_NAME = "kustosamplefiles"
SAS_TOKEN = "?st=2018-08-31T22%3A02%3A25Z&se=2020-09-01T22%3A02%3A00Z&sp=r&sv=2018-03-28&sr=b&sig=LQIbomcKI8Ooz425hWtjeq6d61uEaq21UVX7YrM61N4%3D"
FILE_PATH = "StormEvents.csv"
FILE_SIZE = 64158321    # in bytes

BLOB_PATH = "https://" + ACCOUNT_NAME + ".blob.core.windows.net/" + CONTAINER + "/" + FILE_PATH + SAS_TOKEN

# %%
KUSTO_CLIENT = KustoClient(KCSB_ENGINE)

# %% [markdown]
# ### Create Table in Azure Data Explorer
#
# Click [here](https://docs.microsoft.com/en-us/azure/kusto/management/tables#create-table) for more info on Table commands

# %%
CREATE_TABLE_COMMAND = ".create table StormEvents (StartTime: datetime, EndTime: datetime, EpisodeId: int, EventId: int, State: string, EventType: string, InjuriesDirect: int, InjuriesIndirect: int, DeathsDirect: int, DeathsIndirect: int, DamageProperty: int, DamageCrops: int, Source: string, BeginLocation: string, EndLocation: string, BeginLat: real, BeginLon: real, EndLat: real, EndLon: real, EpisodeNarrative: string, EventNarrative: string, StormSummary: dynamic)"
RESPONSE = KUSTO_CLIENT.execute_mgmt(DB_NAME, CREATE_TABLE_COMMAND)
dataframe_from_result_table(RESPONSE.primary_results[0])
# Out:
#      TableName                                             Schema  \
# 0  StormEvents  {"Name":"StormEvents","OrderedColumns":[{"Name...
#
#   DatabaseName Folder DocString
# 0        cdadb   None      None

# %% [markdown]
# ### Create Ingestion Mapping
#
# Ingestion mapping is required for Azure Data Explorer to map the data in the input file with the table in Azure Data Explorer.
# Click [here](https://docs.microsoft.com/en-us/azure/kusto/management/mappings) for more info on Ingestion Mapping.

# %%
CREATE_MAPPING_COMMAND = """.create table StormEvents ingestion csv mapping 'StormEvents_CSV_Mapping' '[{"Name":"StartTime","datatype":"datetime","Ordinal":0}, {"Name":"EndTime","datatype":"datetime","Ordinal":1},{"Name":"EpisodeId","datatype":"int","Ordinal":2},{"Name":"EventId","datatype":"int","Ordinal":3},{"Name":"State","datatype":"string","Ordinal":4},{"Name":"EventType","datatype":"string","Ordinal":5},{"Name":"InjuriesDirect","datatype":"int","Ordinal":6},{"Name":"InjuriesIndirect","datatype":"int","Ordinal":7},{"Name":"DeathsDirect","datatype":"int","Ordinal":8},{"Name":"DeathsIndirect","datatype":"int","Ordinal":9},{"Name":"DamageProperty","datatype":"int","Ordinal":10},{"Name":"DamageCrops","datatype":"int","Ordinal":11},{"Name":"Source","datatype":"string","Ordinal":12},{"Name":"BeginLocation","datatype":"string","Ordinal":13},{"Name":"EndLocation","datatype":"string","Ordinal":14},{"Name":"BeginLat","datatype":"real","Ordinal":16},{"Name":"BeginLon","datatype":"real","Ordinal":17},{"Name":"EndLat","datatype":"real","Ordinal":18},{"Name":"EndLon","datatype":"real","Ordinal":19},{"Name":"EpisodeNarrative","datatype":"string","Ordinal":20},{"Name":"EventNarrative","datatype":"string","Ordinal":21},{"Name":"StormSummary","datatype":"dynamic","Ordinal":22}]'"""

RESPONSE = KUSTO_CLIENT.execute_mgmt(DB_NAME, CREATE_MAPPING_COMMAND)

dataframe_from_result_table(RESPONSE.primary_results[0])
# Out:
#                       Name Kind  \
# 0  StormEvents_CSV_Mapping  CSV
#
#                                              Mapping  \
# 0  [{"Name":"StartTime","DataType":"datetime","Cs...
#
#                   LastUpdatedOn Database        Table
# 0 2018-11-17 21:01:53.854675400    cdadb  StormEvents

# %% [markdown]
# ### Queue up a message for ingestion
#
# In the below code we are queuing-up a message for Azure Data Explorer to pull data from the Blob storage and ingest the data into Azure Data Explorer.

# %%
INGESTION_CLIENT = KustoIngestClient(KCSB_INGEST)

### All ingestion properties are documented here: https://docs.microsoft.com/en-us/azure/kusto/management/data-ingest#ingestion-properties
INGESTION_PROPERTIES  = IngestionProperties(database=DB_NAME, table=DESTINATION_TABLE, dataFormat=DataFormat.csv, mappingReference=DESTINATION_TABLE_COLUMN_MAPPING, additionalProperties={'ignoreFirstRecord': 'true'})
BLOB_DESCRIPTOR = BlobDescriptor(BLOB_PATH, FILE_SIZE)  # 10 is the raw size of the data in bytes
INGESTION_CLIENT.ingest_from_blob(BLOB_DESCRIPTOR,ingestion_properties=INGESTION_PROPERTIES)

print('Done queuing up ingestion with Azure Data Explorer')
# Out:
# Done queuing up ingestion with Azure Data Explorer

# %% [markdown]
# ### Validate the data was ingested into the table
#
# Wait for 5-10 min for the queued ingestion to schedule the ingest and load the data into Azure Data Explorer. Run the following command to get the count of records in the StormEvents table.

# %%
QUERY = "StormEvents | count"

RESPONSE = KUSTO_CLIENT.execute_query(DB_NAME, QUERY)

dataframe_from_result_table(RESPONSE.primary_results[0])
# Out:
#    Count
# 0  59066

# %% [markdown]
# # Part 3 Query Cluster

# %% [markdown]
# ### Connect to Kusto and execute query
#
# The following command will execute Kusto queries against Help cluster and store the output in Pandas DataFrame

# %%
KUSTO_QUERY  = "StormEvents | sort by StartTime desc | take 1000"

RESPONSE = KUSTO_CLIENT.execute(DB_NAME, KUSTO_QUERY)

# %%
# Explore data in DataFrame

df = dataframe_from_result_table(RESPONSE.primary_results[0])

df
# Out:
#               StartTime             EndTime  EpisodeId  EventId       State  \
# 0   2007-12-31 23:53:00 2007-12-31 23:53:00      12037    65838  CALIFORNIA
# 1   2007-12-31 23:53:00 2007-12-31 23:53:00      12037    65839  CALIFORNIA
# 2   2007-12-31 22:30:00 2007-12-31 23:59:00      12950    71590    MICHIGAN
# 3   2007-12-31 22:30:00 2007-12-31 23:59:00      12950    71589    MICHIGAN
# 4   2007-12-31 22:30:00 2007-12-31 23:59:00      12950    71588    MICHIGAN
# 5   2007-12-31 20:30:00 2007-12-31 23:59:00      12950    71587    MICHIGAN
# 6   2007-12-31 20:30:00 2007-12-31 23:59:00      12950    71586    MICHIGAN
# 7   2007-12-31 19:00:00 2007-12-31 23:59:00      12994    71917      ALASKA
# 8   2007-12-31 19:00:00 2007-12-31 23:59:00      12994    71915      ALASKA
# 9   2007-12-31 18:30:00 2007-12-31 23:59:00      13007    71979  CALIFORNIA
# 10  2007-12-31 15:00:00 2007-12-31 23:59:00      12649    69442     INDIANA
# 11  2007-12-31 15:00:00 2007-12-31 23:59:00      12649    69441     INDIANA
# 12  2007-12-31 15:00:00 2007-12-31 23:59:00      12649    69439     INDIANA
# 13  2007-12-31 15:00:00 2007-12-31 15:00:00      12688    69700        UTAH
# 14  2007-12-31 15:00:00 2007-12-31 23:59:00      12649    69440     INDIANA
# 15  2007-12-31 14:15:00 2007-12-31 20:30:00      12324    67774    ILLINOIS
# 16  2007-12-31 14:15:00 2007-12-31 18:30:00      12324    67770    ILLINOIS
# 17  2007-12-31 14:15:00 2007-12-31 21:00:00      12324    67772    ILLINOIS
# 18  2007-12-31 14:00:00 2007-12-31 23:59:00      12648    69436    ILLINOIS
# 19  2007-12-31 14:00:00 2007-12-31 23:59:00      12648    69434    ILLINOIS
# 20  2007-12-31 14:00:00 2007-12-31 21:00:00      12324    67765    ILLINOIS
# 21  2007-12-31 13:45:00 2007-12-31 18:30:00      12324    67775    ILLINOIS
# 22  2007-12-31 13:15:00 2007-12-31 19:15:00      12324    67766    ILLINOIS
# 23  2007-12-31 13:00:00 2007-12-31 23:59:00      12648    69438    ILLINOIS
# 24  2007-12-31 13:00:00 2007-12-31 23:59:00      12648    69437    ILLINOIS
# 25  2007-12-31 13:00:00 2007-12-31 23:59:00      12648    69435    ILLINOIS
# 26  2007-12-31 13:00:00 2007-12-31 20:00:00      12324    67769    ILLINOIS
# 27  2007-12-31 12:30:00 2007-12-31 19:00:00      12324    67776    ILLINOIS
# 971               0     ...           Trained Spotter
# 972               0     ...       Park/Forest Service
# 973               0     ...                      AWOS
# 974               0     ...                      AWOS
# 975               0     ...           Law Enforcement
# 976               0     ...                      AWOS
# 977               0     ...           Law Enforcement    DENHAM SPGS
# 978               0     ...           Trained Spotter
# 979               0     ...           Trained Spotter
# 980               0     ...           Law Enforcement     GREENSBURG
# 981               0     ...           Trained Spotter
# 982               0     ...           Trained Spotter
# 983               0     ...           Law Enforcement    DENHAM SPGS
# 984               0     ...           Broadcast Media
# 985               0     ...           Trained Spotter
# 986               0     ...                      ASOS
# 987               0     ...                      ASOS
# 988               0     ...           Trained Spotter
# 989               0     ...           Trained Spotter
# 990               0     ...                      AWOS
# 991               0     ...                      AWOS
# 992               0     ...           Trained Spotter
# 993               0     ...           Broadcast Media
# 994               0     ...           Trained Spotter
# 995               0     ...           Trained Spotter
# 996               0     ...           Law Enforcement          FELPS
# 997               0     ...           Trained Spotter
# 998               0     ...           Trained Spotter
# 999               0     ...           Trained Spotter
#
#      EndLocation BeginLat BeginLon   EndLat  EndLon  \
# 0                     NaN      NaN      NaN     NaN
# 1                     NaN      NaN      NaN     NaN
# 2                     NaN      NaN      NaN     NaN
# 3                     NaN      NaN      NaN     NaN
# 4                     NaN      NaN      NaN     NaN
# 5                     NaN      NaN      NaN     NaN
# 6                     NaN      NaN      NaN     NaN
# 7                     NaN      NaN      NaN     NaN
# 8                     NaN      NaN      NaN     NaN
# 9                     NaN      NaN      NaN     NaN
# 10                    NaN      NaN      NaN     NaN
# 11                    NaN      NaN      NaN     NaN
# 12                    NaN      NaN      NaN     NaN
# 13                    NaN      NaN      NaN     NaN
# 14                    NaN      NaN      NaN     NaN
# 15                    NaN      NaN      NaN     NaN
# 16                    NaN      NaN      NaN     NaN
# 17                    NaN      NaN      NaN     NaN
# 18                    NaN      NaN      NaN     NaN
# 19                    NaN      NaN      NaN     NaN
# 20                    NaN      NaN      NaN     NaN
# 21                    NaN      NaN      NaN     NaN
# 22                    NaN      NaN      NaN     NaN
# 23                    NaN      NaN      NaN     NaN
# 24                    NaN      NaN      NaN     NaN
# 25                    NaN      NaN      NaN     NaN
# 26                    NaN      NaN      NaN     NaN
# 27                    NaN      NaN      NaN     NaN
# 28                    NaN      NaN      NaN     NaN
# 29                    NaN      NaN      NaN     NaN
# ..           ...      ...      ...      ...     ...
# 970                   NaN      NaN      NaN     NaN
# 971                   NaN      NaN      NaN     NaN
# 972                   NaN      NaN      NaN     NaN
# 973                   NaN      NaN      NaN     NaN
# 974                   NaN      NaN      NaN     NaN
# 975                   NaN      NaN      NaN     NaN
# 976                   NaN      NaN      NaN     NaN
# 977  DENHAM SPGS -90.9500    30.48 -90.9500     NaN
# 978                   NaN      NaN      NaN     NaN
# 979                   NaN      NaN      NaN     NaN
# 980   GREENSBURG -90.6700    30.82 -90.6700     NaN
# 981                   NaN      NaN      NaN     NaN
# 982                   NaN      NaN      NaN     NaN
# 983  DENHAM SPGS -90.9500    30.48 -90.9500     NaN
# 984                   NaN      NaN      NaN     NaN
# 985                   NaN      NaN      NaN     NaN
# 986                   NaN      NaN      NaN     NaN
# 987                   NaN      NaN      NaN     NaN
# 988                   NaN      NaN      NaN     NaN
# 989                   NaN      NaN      NaN     NaN
# 990                   NaN      NaN      NaN     NaN
# 991                   NaN      NaN      NaN     NaN
# 992                   NaN      NaN      NaN     NaN
# 993                   NaN      NaN      NaN     NaN
# 994                   NaN      NaN      NaN     NaN
# 995                   NaN      NaN      NaN     NaN
# 996        FELPS -90.8356    30.97 -90.8356     NaN
# 997                   NaN      NaN      NaN     NaN
# 998                   NaN      NaN      NaN     NaN
# 999                   NaN      NaN      NaN     NaN
#
#                                       EpisodeNarrative  \
# 0    The Warm Springs RAWS sensor reported northerl...
# 1    North to northeast winds gusting to around 58 ...
# 2    This heavy snow event continued into the early...
# 3    This heavy snow event continued into the early...
# 4    This heavy snow event continued into the early...
# 5    This heavy snow event continued into the early...
# 6    This heavy snow event continued into the early...
# 7    Craig reported very windy with higher gusts fr...
# 8    Sitka observed a measured gust of 48 MPH at 22...
# 9    A 72 mph wind gusts was measured by the Tonner...
# 10   Storm total snowfall near Wheatfield was 7.6 i...
# 11   Storm total snowfall near Morroco was 7.0 inches.
# 12   Storm total snowfall near Crown Point was 7.8 ...
# 13   Three experienced snowmobilers were riding in ...
# 14   Storm total snowfall near Valparaiso was 8.1 i...
# 15
# 16
# 17
# 18   Storm total snowfall near Barrington was 6.6 i...
# 19   Storm total snowfall near Lake Villa was 6.5 i...
# 20
# 21
# 22
# 23   Storm total snowfall near Momence was 7.2 inches.
# 24     Storm total snowfall near Crete was 6.5 inches.
# 25     Storm total snowfall near Elgin was 6.2 inches.
# 26
# 27
# 28
# 29
# ..                                                 ...
# 970
# 971
# 972
# 973
# 974
# 975
# 976
# 977  Numerous trees were blown down across the west...
# 978
# 979
# 980                 A tree was blown down on Guy Road.
# 981
# 982
# 983       Thunderstorm winds knocked down power lines.
# 984  Some trees and power lines were blown down in ...
# 985
# 986
# 987
# 988
# 989
# 990
# 991
# 992
# 993  Some trees and power lines were blown down in ...
# 994
# 995
# 996  Thunderstorm winds knocked down five trees nea...
# 997
# 998
# 999
#
#                                         EventNarrative StormSummary
# 0    {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 1    {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 2    {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 3    {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 4    {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 5    {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 6    {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 7    {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 8    {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 9    {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 10   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 11   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 12   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 13   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 14   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 15   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 16   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 17   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 18   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 19   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 20   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 21   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 22   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 23   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 24   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 25   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 26   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 27   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 28   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 29   {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# ..                                                 ...          ...
# 970  {\r\n  "TotalDamages": 5000,\r\n  "StartTime":...         None
# 971  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 972  {\r\n  "TotalDamages": 5000,\r\n  "StartTime":...         None
# 973  {\r\n  "TotalDamages": 5000,\r\n  "StartTime":...         None
# 974  {\r\n  "TotalDamages": 5000,\r\n  "StartTime":...         None
# 975  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 976  {\r\n  "TotalDamages": 5000,\r\n  "StartTime":...         None
# 977  {\r\n  "TotalDamages": 2000,\r\n  "StartTime":...         None
# 978  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 979  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 980  {\r\n  "TotalDamages": 250,\r\n  "StartTime": ...         None
# 981  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 982  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 983  {\r\n  "TotalDamages": 1000,\r\n  "StartTime":...         None
# 984  {\r\n  "TotalDamages": 20000,\r\n  "StartTime"...         None
# 985  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 986  {\r\n  "TotalDamages": 5000,\r\n  "StartTime":...         None
# 987  {\r\n  "TotalDamages": 5000,\r\n  "StartTime":...         None
# 988  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 989  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 990  {\r\n  "TotalDamages": 5000,\r\n  "StartTime":...         None
# 991  {\r\n  "TotalDamages": 5000,\r\n  "StartTime":...         None
# 992  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 993  {\r\n  "TotalDamages": 20000,\r\n  "StartTime"...         None
# 994  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 995  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 996  {\r\n  "TotalDamages": 1000,\r\n  "StartTime":...         None
# 997  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 998  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
# 999  {\r\n  "TotalDamages": 0,\r\n  "StartTime": "2...         None
#
# [1000 rows x 22 columns]
